# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head(2)
# Out:
#              tweet_id airline_sentiment    airline airline_sentiment_gold  \
# 0  567900433542488064          negative  Southwest                    NaN
# 1  569989168903819264          positive  Southwest                    NaN
#
#             name negativereason_gold  retweet_count  \
# 0  ColeyGirouard                 NaN              0
# 1  WalterFaddoul                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @SouthwestAir I am scheduled for the morning, ...         NaN
# 1  @SouthwestAir seeing your workers time in and ...         NaN
#
#                tweet_created              tweet_location  \
# 0  2015-02-17 20:16:29 -0800             Washington D.C.
# 1  2015-02-23 14:36:22 -0800  Indianapolis, Indiana; USA
#
#                 user_timezone
# 0      Atlantic Time (Canada)
# 1  Central Time (US & Canada)

# %%
train.count()
# Out:
# tweet_id                  10980
# airline_sentiment         10980
# airline                   10980
# airline_sentiment_gold       31
# name                      10980
# negativereason_gold          24
# retweet_count             10980
# text                      10980
# tweet_coord                 776
# tweet_created             10980
# tweet_location             7430
# user_timezone              7403
# dtype: int64

# %%
# Dropping Useless Columns

train.drop('tweet_id', inplace = True, axis = 1)
train.drop('airline_sentiment_gold', inplace = True, axis = 1)
train.drop('negativereason_gold', inplace = True, axis = 1)
train.drop('tweet_coord', inplace = True, axis = 1)
train.drop('tweet_created',inplace = True, axis = 1)

# %%
train
# Out:
#       airline_sentiment     airline             name  retweet_count  \
# 0              negative   Southwest    ColeyGirouard              0
# 1              positive   Southwest    WalterFaddoul              0
# 2              positive      United        LocalKyle              0
# 3              negative   Southwest      amccarthy19              0
# 4              negative      United          J_Okayy              0
# 5              negative      United       bobgiolito              0
# 6              negative       Delta     aaronkinnari              0
# 7              positive       Delta      TimothySays              0
# 8              negative      United         lindaSWC              1
# 9              positive   Southwest           amyums              0
# 10             negative   Southwest          Faultie              0
# 11              neutral       Delta        tonymbove              0
# 12             positive  US Airways      sherrylweir              0
# 13             negative   Southwest        Mselite25              0
# 14             negative  US Airways     KennethBracy              0
# 15             negative  US Airways       SyncSummit              0
# 16             negative    American    Lioninflorida              0
# 17             negative       Delta          TheBuie             22
# 18             negative       Delta        TheRealOx              0
# 19             negative    American       Rizzilient              0
# 20             negative  US Airways  TomFutureforall              0
# 21              neutral   Southwest     DoctorFox007              0
# 22             negative  US Airways   chrisseifert83              0
# 23             negative      United    JeffPKirkland              0
# 24             positive      United    jonatzzValdez              0
# 25              neutral      United         MusseZam              0
# 26             negative       Delta        Old_bauer              0
# 27             negative      United        KeenanPam              0
# 28             positive   Southwest      Salem_Eways              0
# 29             positive    American        MarkMan23              0
# ...                 ...         ...              ...            ...
# 10950          positive       Delta  Dress4YesConJax              0
# 10951          negative   Southwest     horacioguapo              0
# 10952          negative   Southwest    Angela_Meyers              0
# 10953          negative      United         Jo_Frost              0
# 10954          negative   Southwest     thirty_lives              0
# 10955          negative       Delta        4TONEMENT              0
# 10956           neutral   Southwest       BobbiStorm              0
# 10957          negative  US Airways      VirginiaRmz              0
# 10958          negative      United         nate2482              0
# 10959          negative  US Airways       dave_cavan              0
# 10960          negative      United     iamawarplane              1
# 10961          negative       Delta          rosenrj              0
# 10962           neutral      United         gwen1013              0
# 10963          negative  US Airways      dailylaurel              0
# 10964          negative      United      johnwoodRTR              0
# 10965           neutral      United      8629Fissile              0
# 10966          negative      United          Brennej              0
# 10967          negative   Southwest      mrshossruns              0
# 10968          negative    American   vickie_frisbie              0
# 10969          positive   Southwest      stefughknee              0
# 10970          negative   Southwest        slobotski              0
# 10971           neutral       Delta      mutantgatto              0
# 10972          negative  US Airways           m2gris              0
# 10973          negative    American  realscooterward              0
# 10974          positive   Southwest   happygirlvicki              0
# 10975           neutral    American    Cottopanama85              0
# 10976          positive      United     PaulBEsteves              0
# 10977          negative  US Airways      runfixsteve              0
# 10978          negative  US Airways       CLChicosky              0
# 10979          negative      United       JW_Blocker              1
#
#                                                     text  \
# 0      @SouthwestAir I am scheduled for the morning, ...
# 1      @SouthwestAir seeing your workers time in and ...
# 2      @united Flew ORD to Miami and back and  had gr...
# 3         @SouthwestAir @dultch97 that's horse radish 😤🐴
# 4      @united so our flight into ORD was delayed bec...
# 5      @united Why did you load us in this flying sar...
# 6      @JetBlue that is a stock response. Delays not ...
# 7      @JetBlue That'd be nice! Hoping to rack up eno...
# 8      @united frankly worse customer service ever. P...
# 9      @SouthwestAir yeah haha. Never been in one. It...
# 10     @SouthwestAir MCO-&gt;DCA flight almost full o...
# 11     @JetBlue what's the easiest way to get a ticke...
# 12     @USAirways - love the changes in the lounge - ...
# 13     @SouthwestAir I receive bad customer service a...
# 14     @USAirways you're killing me sche a flight to ...
# 15     @USAirways 8 weeks to refund this ticket - 037...
# 16     @AmericanAir no private msg me and will provid...
# 17     can you not? RT @JetBlue Our fleet's on fleek....
# 18     @JetBlue any info on why flight 704 from SJU t...
# 19     @AmericanAir, I've tried no less than 8 times ...
# 20     @USAirways new problem...had wrong last name o...
# 21     @SouthwestAir Any possible chance of SWA bring...
# 22     @USAirways @AmericanAir who runs the show at t...
# 23     @united computers are down but you stopped giv...
# 24             @united good fly!! #United #businessFirst
# 25     @united I am flying from msp to dxb, my child ...
# 26     @JetBlue loves Cancelled Flightling tickets an...
# 27     @united In ORD, waited 20 min after crew membe...
# 28     @SouthwestAir Jason (108639) at Gate #3 in SAN...
# 29     @AmericanAir everything for sorted out. Thanks...
# ...                                                  ...
# 10950  @JetBlue Even though this flight #226 didn't h...
# 10951  @SouthwestAir very disappointed in your handli...
# 10952  @SouthwestAir flight Cancelled Flightled out o...
# 10953  @united when I read it say ' in some cases' ca...
# 10954  @SouthwestAir you're giving everyone tix for #...
# 10955  @JetBlue Am I the only one who had to look tha...
# 10956                    @SouthwestAir go south everyone
# 10957  @USAirways 4 hours Late Flightr And i lost my ...
# 10958  @united I sure did.   I had to drive a total o...
# 10959  @USAirways his name is Rett Cavan, he has a go...
# 10960  @united 3 times my flight has been delayed and...
# 10961  @JetBlue there is no supervisor available, so ...
# 10962                                  @united following
# 10963  @USAirways even alternate options are allready...
# 10964  @united Also your at-gate monitor showed 23 em...
# 10965                             @united Okay thank you
# 10966  @united - vacation days: relevant, Ritz in PR ...
# 10967  @SouthwestAir you guys there? Are we on hour 2...
# 10968  @AmericanAir we are through. I can quit you. I...
# 10969          @SouthwestAir thank you! ❤️❤️❤️ you guys!
# 10970  @SouthwestAir went to purchase a flight that I...
# 10971  @JetBlue by any chance do u offer fresh guacam...
# 10972  @USAirways - 53 minutes on hold for a reservat...
# 10973  @AmericanAir the worst air experience I have e...
# 10974  @SouthwestAir beautiful view flying into San J...
# 10975                            @AmericanAir followback
# 10976  @united thanks for the help. Wish the phone re...
# 10977  @usairways the. Worst. Ever. #dca #customerser...
# 10978  @nrhodes85: look! Another apology. DO NOT FLY ...
# 10979  @united you are by far the worst airline. 4 pl...
#
#                        tweet_location                user_timezone
# 0                     Washington D.C.       Atlantic Time (Canada)
# 1          Indianapolis, Indiana; USA   Central Time (US & Canada)
# 2                            Illinois   Central Time (US & Canada)
# 3                                 NaN       Atlantic Time (Canada)
# 4                                 NaN   Eastern Time (US & Canada)
# 5                     Los Angeles, CA   Pacific Time (US & Canada)
# 6                              Gotham                        Quito
# 7                      Burlington, MA   Eastern Time (US & Canada)
# 8                                 NaN                          NaN
# 9                                 NaN   Central Time (US & Canada)
# 10                               D.C.                          NaN
# 11                      Cambridge, MA                        Quito
# 12                                NaN                        Quito
# 13                  Rite behind my $$  Mountain Time (US & Canada)
# 14             Where ever God puts me                          NaN
# 15     Where Music meets Visual Media   Eastern Time (US & Canada)
# 16                Fort Myers, Florida   Eastern Time (US & Canada)
# 17                        Raleigh, NC   Eastern Time (US & Canada)
# 18                                NaN   Eastern Time (US & Canada)
# 19                                NaN                          NaN
# 20                                NaN                          NaN
# 21           ÜT: 40.819919,-73.864869   Eastern Time (US & Canada)
# 22                       Stamford, Ct   Eastern Time (US & Canada)
# 23                             Oregon   Pacific Time (US & Canada)
# 24                             Mexico   Central Time (US & Canada)
# 25                                NaN                          NaN
# 26                                NaN   Eastern Time (US & Canada)
# 27                                NaN                          NaN
# 28                                NaN                          NaN
# 29                      San Diego, CA   Pacific Time (US & Canada)
# ...                               ...                          ...
# 10950                            NYC                           NaN
# 10951                             NaN                          NaN
# 10952                     Hershey, PA   Eastern Time (US & Canada)
# 10953                          Global                        Quito
# 10954                      ʞᴚoʎ   ʍǝu   Eastern Time (US & Canada)
# 10955                             NaN   Eastern Time (US & Canada)
# 10956                           Miami                          NaN
# 10957                    Mexico, D.F.   Central Time (US & Canada)
# 10958                 Parkersburg, WV   Eastern Time (US & Canada)
# 10959                     Livonia, MI                          NaN
# 10960                   Austin, Texas                          NaN
# 10961                             NaN                          NaN
# 10962                   New Haven, CT                          NaN
# 10963  Bruxelle-Paris-Marseille-(BPM)                       Athens
# 10964                       Hong Kong   Eastern Time (US & Canada)
# 10965                             NaN                       London
# 10966                             NaN                          NaN
# 10967                             NaN   Eastern Time (US & Canada)
# 10968                   Dallas, Texas  Mountain Time (US & Canada)
# 10969                             NaN                          NaN
# 10970             Midwest + Airplanes   Central Time (US & Canada)
# 10971                         ravioli   Eastern Time (US & Canada)
# 10972                      Irvine, Ca                          NaN
# 10973                  washington, dc   Eastern Time (US & Canada)
# 10974                 Omaha, Nebraska   Central Time (US & Canada)
# 10975                     ohio,panama                          NaN
# 10976                        Brooklyn   Eastern Time (US & Canada)
# 10977          St. Augustine, Florida                          NaN
# 10978                             NaN                          NaN
# 10979                             NaN                          NaN
#
# [10980 rows x 7 columns]

# %%
train.head(2)
# Out:
#   airline_sentiment    airline           name  retweet_count  \
# 0          negative  Southwest  ColeyGirouard              0
# 1          positive  Southwest  WalterFaddoul              0
#
#                                                 text  \
# 0  @SouthwestAir I am scheduled for the morning, ...
# 1  @SouthwestAir seeing your workers time in and ...
#
#                tweet_location               user_timezone
# 0             Washington D.C.      Atlantic Time (Canada)
# 1  Indianapolis, Indiana; USA  Central Time (US & Canada)

# %% [markdown]
# ### Filling NaN values

# %%
mood_count = train['airline_sentiment'].value_counts()
mood_count
# Out:
# negative    6851
# neutral     2327
# positive    1802
# Name: airline_sentiment, dtype: int64

# %%
train['airline'].value_counts()
# Out:
# United            2928
# US Airways        2152
# American          2078
# Southwest         1817
# Delta             1639
# Virgin America     366
# Name: airline, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['airline_sentiment'] = le.fit_transform(train['airline_sentiment'])
train.head(2)
# Out:
#    airline_sentiment    airline           name  retweet_count  \
# 0                  0  Southwest  ColeyGirouard              0
# 1                  2  Southwest  WalterFaddoul              0
#
#                                                 text  \
# 0  @SouthwestAir I am scheduled for the morning, ...
# 1  @SouthwestAir seeing your workers time in and ...
#
#                tweet_location               user_timezone
# 0             Washington D.C.      Atlantic Time (Canada)
# 1  Indianapolis, Indiana; USA  Central Time (US & Canada)

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
def tweet_to_words(raw_tweet):
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet) 
    words = letters_only.lower().split()                             
    stops = set(stopwords.words("english"))                  
    meaningful_words = [w for w in words if not w in stops] 
    return( " ".join( meaningful_words ))

# %%
train['clean_tweet'] = train['text'].apply(lambda x: tweet_to_words(x))

test['clean_tweet'] = test['text'].apply(lambda x: tweet_to_words(x))

# %%
train_clean_tweet=[]
for tweet in train['clean_tweet']:
    train_clean_tweet.append(tweet)
    
test_clean_tweet=[]
for tweet in test['clean_tweet']:
    test_clean_tweet.append(tweet)

# %%
from sklearn.feature_extraction.text import CountVectorizer
v = CountVectorizer(analyzer = "word")
train_features= v.fit_transform(train_clean_tweet)
test_features= v.transform(test_clean_tweet)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb = MultinomialNB()

# %%
nb.fit(train_features,train['airline_sentiment'])
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy = accuracy_score(nb.predict(train_features),train['airline_sentiment'])
print(accuracy)
# Out:
# 0.8437158469945355

# %%
test_pred = nb.predict(test_features)
test_pred = le.inverse_transform(test_pred)
print(test_pred)
np.savetxt("test_pred.csv",test_pred,fmt='%s')
# Out:
# ['negative' 'negative' 'negative' ... 'neutral' 'positive' 'neutral']
# /home/deepak/Anaconda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators = 200)

# %%
clf.fit(train_features,train['airline_sentiment'])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy = accuracy_score(clf.predict(train_features),train['airline_sentiment'])
print(accuracy)

# %%
test_pred = clf.predict(test_features)

# %%
test_pred = le.inverse_transform(test_pred)

# %%
np.savetxt("test_pred.csv",test_pred,fmt='%s')

# %%
print(test_pred)
